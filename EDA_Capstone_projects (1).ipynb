# %% [markdown]
# <h2>Importing Libraries</h2>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("C:\\Users\\krish\\Desktop\\DataAnalyst_Class\\data_Clean\\List of Countries by Sugarcane Production.csv")

# %%
df.shape
# Out:
# (103, 7)

# %%
df.head()
# Out:
#    Unnamed: 0   Country      Continent Production (Tons)  \
# 0           0    Brazil  South America       768.678.382
# 1           1     India           Asia       348.448.000
# 2           2     China           Asia       123.059.739
# 3           3  Thailand           Asia        87.468.496
# 4           4  Pakistan           Asia        65.450.704
#
#   Production per Person (Kg) Acreage (Hectare) Yield (Kg / Hectare)
# 0                  3.668,531        10.226.205             75.167,5
# 1                     260721         4.950.000             70.393,5
# 2                      88287         1.675.215             73.459,1
# 3                  1.264,303         1.336.575             65.442,2
# 4                     324219         1.130.820               57.879

# %%
df.tail(5)
# Out:
#      Unnamed: 0    Country Continent Production (Tons)  \
# 98           98    Lebanon      Asia                97
# 99           99   Djibouti    Africa                53
# 100         100  Singapore      Asia                50
# 101         101      Samoa   Oceania                12
# 102         102      Syria      Asia                 1
#
#     Production per Person (Kg) Acreage (Hectare) Yield (Kg / Hectare)
# 98                          16                 3             28.386,4
# 99                          51               NaN                  NaN
# 100                          9                 2                   25
# 101                          6                 1             11.949,8
# 102                          0                 0             83.034,2

# %%
df.sample()
# Out:
#     Unnamed: 0 Country Continent Production (Tons) Production per Person (Kg)  \
# 64          64  Taiwan      Asia             395.8                      16788
#
#    Acreage (Hectare) Yield (Kg / Hectare)
# 64             5.917             66.896,6

# %% [markdown]
# <h2>Data cleaning</h2>

# %%
df["Production (Tons)"] = df["Production (Tons)"].str.replace(".","")
df["Production per Person (Kg)"] = df["Production per Person (Kg)"].str.replace(".","").str.replace(",",".")
df["Acreage (Hectare)"] = df["Acreage (Hectare)"].str.replace(".","")
df["Yield (Kg / Hectare)"] = df["Yield (Kg / Hectare)"].str.replace(".","").str.replace(",",".")

# %%
df.head(5)
# Out:
#    Unnamed: 0   Country      Continent Production (Tons)  \
# 0           0    Brazil  South America         768678382
# 1           1     India           Asia         348448000
# 2           2     China           Asia         123059739
# 3           3  Thailand           Asia          87468496
# 4           4  Pakistan           Asia          65450704
#
#   Production per Person (Kg) Acreage (Hectare) Yield (Kg / Hectare)
# 0                   3668.531          10226205              75167.5
# 1                     260721           4950000              70393.5
# 2                      88287           1675215              73459.1
# 3                   1264.303           1336575              65442.2
# 4                     324219           1130820                57879

# %%
df = df.drop("Unnamed: 0", axis = 1)

# %%
df.head()
# Out:
#     Country      Continent Production (Tons) Production per Person (Kg)  \
# 0    Brazil  South America         768678382                   3668.531
# 1     India           Asia         348448000                     260721
# 2     China           Asia         123059739                      88287
# 3  Thailand           Asia          87468496                   1264.303
# 4  Pakistan           Asia          65450704                     324219
#
#   Acreage (Hectare) Yield (Kg / Hectare)
# 0          10226205              75167.5
# 1           4950000              70393.5
# 2           1675215              73459.1
# 3           1336575              65442.2
# 4           1130820                57879

# %%
df.rename(columns ={"Production (Tons)": "Production(Tons)"}, inplace = True)
df.rename(columns ={"Production per Person (Kg)": "Production_per_Person(Kg)"}, inplace = True)
df.rename(columns ={"Acreage (Hectare)": "Acreage(Hectare)"}, inplace = True)
df.rename(columns ={"Yield (Kg / Hectare)": "Yield(Kg/Hectare)"}, inplace = True)

# %%
df.head()
# Out:
#     Country      Continent Production(Tons) Production_per_Person(Kg)  \
# 0    Brazil  South America        768678382                  3668.531
# 1     India           Asia        348448000                    260721
# 2     China           Asia        123059739                     88287
# 3  Thailand           Asia         87468496                  1264.303
# 4  Pakistan           Asia         65450704                    324219
#
#   Acreage(Hectare) Yield(Kg/Hectare)
# 0         10226205           75167.5
# 1          4950000           70393.5
# 2          1675215           73459.1
# 3          1336575           65442.2
# 4          1130820             57879

# %%
df.isna().sum()
# Out:
# Country                      0
# Continent                    0
# Production(Tons)             0
# Production_per_Person(Kg)    0
# Acreage(Hectare)             1
# Yield(Kg/Hectare)            1
# dtype: int64

# %%
df[df["Acreage(Hectare)"].isnull()]
# Out:
#      Country Continent Production(Tons) Production_per_Person(Kg)  \
# 99  Djibouti    Africa               53                        51
#
#    Acreage(Hectare) Yield(Kg/Hectare)
# 99              NaN               NaN

# %%
df = df.dropna().reset_index().drop("index", axis=1)

# %%
df
# Out:
#        Country      Continent Production(Tons) Production_per_Person(Kg)  \
# 0       Brazil  South America        768678382                  3668.531
# 1        India           Asia        348448000                    260721
# 2        China           Asia        123059739                     88287
# 3     Thailand           Asia         87468496                  1264.303
# 4     Pakistan           Asia         65450704                    324219
# ..         ...            ...              ...                       ...
# 97       Spain         Europe              394                         8
# 98     Lebanon           Asia               97                        16
# 99   Singapore           Asia               50                         9
# 100      Samoa        Oceania               12                         6
# 101      Syria           Asia                1                         0
#
#     Acreage(Hectare) Yield(Kg/Hectare)
# 0           10226205           75167.5
# ...

# %%
df.nunique()
# Out:
# Country                      102
# Continent                      6
# Production(Tons)             102
# Production_per_Person(Kg)    101
# Acreage(Hectare)             101
# Yield(Kg/Hectare)            102
# dtype: int64

# %%
df.dtypes
# Out:
# Country                      object
# Continent                    object
# Production(Tons)             object
# Production_per_Person(Kg)    object
# Acreage(Hectare)             object
# Yield(Kg/Hectare)            object
# dtype: object

# %%
df.head()
# Out:
#     Country      Continent Production(Tons) Production_per_Person(Kg)  \
# 0    Brazil  South America        768678382                  3668.531
# 1     India           Asia        348448000                    260721
# 2     China           Asia        123059739                     88287
# 3  Thailand           Asia         87468496                  1264.303
# 4  Pakistan           Asia         65450704                    324219
#
#   Acreage(Hectare) Yield(Kg/Hectare)
# 0         10226205           75167.5
# 1          4950000           70393.5
# 2          1675215           73459.1
# 3          1336575           65442.2
# 4          1130820             57879

# %%
df["Production(Tons)"] = df["Production(Tons)"].astype(float)
df["Production_per_Person(Kg)"] = df["Production_per_Person(Kg)"].astype(float)
df["Acreage(Hectare)"] = df["Acreage(Hectare)"].astype(float)
df["Yield(Kg/Hectare)"] = df["Yield(Kg/Hectare)"].astype(float)

# %%
df.dtypes
# Out:
# Country                       object
# Continent                     object
# Production(Tons)             float64
# Production_per_Person(Kg)    float64
# Acreage(Hectare)             float64
# Yield(Kg/Hectare)            float64
# dtype: object

# %% [markdown]
# <h2>Univariate Analysis</h2>

# %%
df.head()
# Out:
#     Country      Continent  Production(Tons)  Production_per_Person(Kg)  \
# 0    Brazil  South America       768678382.0                   3668.531
# 1     India           Asia       348448000.0                 260721.000
# 2     China           Asia       123059739.0                  88287.000
# 3  Thailand           Asia        87468496.0                   1264.303
# 4  Pakistan           Asia        65450704.0                 324219.000
#
#    Acreage(Hectare)  Yield(Kg/Hectare)
# 0        10226205.0            75167.5
# 1         4950000.0            70393.5
# 2         1675215.0            73459.1
# 3         1336575.0            65442.2
# 4         1130820.0            57879.0

# %% [markdown]
# <h2>How many countries produce sugarcane from each continuent?</h2>

# %%
df["Continent"].value_counts()
# Out:
# Continent
# Africa           38
# Asia             25
# North America    22
# South America    11
# Oceania           4
# Europe            2
# Name: count, dtype: int64

# %%
df["Continent"].value_counts().plot(kind = "bar")
# Out:
# <Axes: xlabel='Continent'>

# %%
df.describe()
# Out:
#        Production(Tons)  Production_per_Person(Kg)  Acreage(Hectare)  \
# count      1.020000e+02                 102.000000      1.020000e+02
# mean       1.850372e+07              112952.435755      2.498981e+05
# std        8.419149e+07              176651.341929      1.137003e+06
# min        1.000000e+00                   0.000000      0.000000e+00
# 25%        6.251875e+04                3671.910000      1.104000e+03
# 50%        1.440044e+06               25572.500000      1.655800e+04
# 75%        6.426824e+06              146384.750000      8.047400e+04
# max        7.686784e+08              951087.000000      1.022620e+07
#
#        Yield(Kg/Hectare)
# count         102.000000
# mean        52628.078431
# std         30504.676683
# min            10.000000
# 25%         29072.025000
# 50%         54108.950000
# 75%         73282.700000
# max        129049.300000

# %% [markdown]
# <h2> Checking Outliers</h2>

# %%
plt.figure(figsize = (10,8))
plt.subplot(2,2,1)
sns.boxplot(df["Production(Tons)"])
plt.title("Production(Tons)")
plt.subplot(2,2,2)
sns.boxplot(df["Production_per_Person(Kg)"])
plt.title("Production_per_person(Kg)")
plt.subplot(2,2,3)
sns.boxplot(df["Acreage(Hectare)"])
plt.title("Acreage(Hectare)")
plt.subplot(2,2,4)
sns.boxplot(df["Yield(Kg/Hectare)"])
plt.title("Yield(Kg/Hectare)")
plt.show()

# %% [markdown]
# <h2>Distribution of the columns</h2>

# %%
plt.figure(figsize = (10,10))
plt.subplot(2,2,1)
sns.histplot(df["Production(Tons)"])
plt.title("Production(Tons)")
plt.subplot(2,2,2)
sns.histplot(df["Production_per_Person(Kg)"])
plt.title("Production_per_Person(Kg)")
plt.subplot(2,2,3)
sns.histplot(df["Acreage(Hectare)"])
plt.title("Acreage(Hectare)")
plt.subplot(2,2,4)
sns.histplot(df["Yield(Kg/Hectare)"])
sns.boxplot(df["Yield(Kg/Hectare)"])
plt.title("Yield(Kg/Hectare)")
plt.show()

# %%
######sns.kdeplot(df["Acreage(Hectare)"], fill=True) -- to understand the kdeplot
# Out:
# <Axes: xlabel='Acreage(Hectare)', ylabel='Density'>

# %% [markdown]
# <h2>Bivariate Analysis</h2>

# %%
df_new = df[["Country","Production(Tons)"]].set_index("Country")

# %%
df_new
# Out:
#            Production(Tons)
# Country
# Brazil          768678382.0
# India           348448000.0
# China           123059739.0
# Thailand         87468496.0
# Pakistan         65450704.0
# ...                     ...
# Spain                 394.0
# Lebanon                97.0
# Singapore              50.0
# Samoa                  12.0
# Syria                   1.0
#
# [102 rows x 1 columns]

# %%
df_new["Production(Tons)"].sum()
# Out:
# 1887379367.0

# %%
df_new["Production(Tons)_percent"] = df_new["Pructionod(Tons)"]*100/df_new["Production(Tons)"].sum()

# %%
df_new["Production(Tons)_percent"]
# Out:
# Country
# Brazil       4.072729e+01
# India        1.846200e+01
# China        6.520138e+00
# Thailand     4.634389e+00
# Pakistan     3.467809e+00
#                  ...
# Spain        2.087551e-05
# Lebanon      5.139401e-06
# Singapore    2.649176e-06
# Samoa        6.358022e-07
# Syria        5.298352e-08
# Name: Production(Tons)_percent, Length: 102, dtype: float64

# %%
df_new
# Out:
#            Production(Tons)  Production(Tons)_percent
# Country
# Brazil          768678382.0              4.072729e+01
# India           348448000.0              1.846200e+01
# China           123059739.0              6.520138e+00
# Thailand         87468496.0              4.634389e+00
# Pakistan         65450704.0              3.467809e+00
# ...                     ...                       ...
# Spain                 394.0              2.087551e-05
# Lebanon                97.0              5.139401e-06
# Singapore              50.0              2.649176e-06
# Samoa                  12.0              6.358022e-07
# Syria                   1.0              5.298352e-08
#
# [102 rows x 2 columns]

# %%
df_new["Production(Tons)_percent"].plot(kind = "pie", autopct = "%.2f")
# Out:
# <Axes: ylabel='Production(Tons)_percent'>

# %%
#df_new1 = df[["Continent","Production(Tons)"]].set_index("Continent")

# %%
#df_new1["Production(Tons)_percent"] = df_new1["Production(Tons)"]*100/df_new1["Production(Tons)"].sum()

# %%
#df_new1["Production(Tons)_percent"].plot(kind = "pie", autopct = "%.2f")
# Out:
# <Axes: ylabel='Production(Tons)_percent'>

# %%
df[["Country","Production(Tons)"]].set_index("Country").sort_values("Production(Tons)", ascending = False).head(15).plot(kind = "bar")
# Out:
# <Axes: xlabel='Country'>

# %%
ax = sns.barplot(data = df.head(15),  x= "Country", y = "Production(Tons)")
ax.set_xticklabels(ax.get_xticklabels(),rotation =90)
plt.show()
# Out:
# C:\Users\krish\AppData\Local\Temp\ipykernel_23680\2823669880.py:2: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(),rotation =90)

# %% [markdown]
# <h2>Which country has highest land</h2>

# %%
df_acr = df.sort_values("Acreage(Hectare)", ascending = False).head(15)
ax = sns.barplot(data = df_acr,  x= "Country", y = "Acreage(Hectare)")
ax.set_xticklabels(ax.get_xticklabels(),rotation =90)
plt.show()
# Out:
# C:\Users\krish\AppData\Local\Temp\ipykernel_23680\2973715568.py:3: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(),rotation =90)

# %% [markdown]
# <h2>Which country has highest yield per hectrare</h2>

# %%
df_yield = df.sort_values("Yield(Kg/Hectare)", ascending = False).head(15)
ax = sns.barplot(data = df_yield,  x= "Country", y = "Yield(Kg/Hectare)")
ax.set_xticklabels(ax.get_xticklabels(),rotation =90)
plt.show()
# Out:
# C:\Users\krish\AppData\Local\Temp\ipykernel_23680\2860594357.py:3: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(),rotation =90)

# %%
df_yield = df.sort_values("Production_per_Person(Kg)", ascending = False).head(15)
ax = sns.barplot(data = df_yield,  x= "Country", y = "Production_per_Person(Kg)")
ax.set_xticklabels(ax.get_xticklabels(),rotation =90)
plt.show()
# Out:
# C:\Users\krish\AppData\Local\Temp\ipykernel_23680\1543583186.py:3: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(),rotation =90)

# %%
Correlation

# %%
df.corr(numeric_only=True)
# Out:
#                            Production(Tons)  Production_per_Person(Kg)  \
# Production(Tons)                   1.000000                   0.015000
# Production_per_Person(Kg)          0.015000                   1.000000
# Acreage(Hectare)                   0.997550                   0.012557
# Yield(Kg/Hectare)                  0.132812                   0.017999
#
#                            Acreage(Hectare)  Yield(Kg/Hectare)
# Production(Tons)                   0.997550           0.132812
# Production_per_Person(Kg)          0.012557           0.017999
# Acreage(Hectare)                   1.000000           0.113433
# Yield(Kg/Hectare)                  0.113433           1.000000

# %%
sns.heatmap(df.corr(numeric_only=True), annot = True, cmap="Greens")
# Out:
# <Axes: >

# %%
sns.scatterplot(data = df, x = "Acreage(Hectare)", y = "Production(Tons)", hue = "Continent" )
# Out:
# <Axes: xlabel='Acreage(Hectare)', ylabel='Production(Tons)'>

# %%
df_continent = df.groupby("Continent").sum()

# %%
df_continent["Production(Tons)"].sort_values(ascending =  False).plot(kind = "bar")
# Out:
# <Axes: xlabel='Continent'>

# %%
df_continent
# Out:
#                                                          Country  \
# Continent
# Africa         EgyptSouth AfricaKenyaSwazilandSudanZambiaMaur...
# Asia           IndiaChinaThailandPakistanIndonesiaPhilippines...
# Europe                                             PortugalSpain
# North America  MexicoGuatemalaUnited States of AmericaCubaEl ...
# Oceania                       AustraliaFijiPapua New GuineaSamoa
# South America  BrazilColombiaArgentinaPeruEcuadorBoliviaParag...
#
#                Production(Tons)  Production_per_Person(Kg)  Acreage(Hectare)  \
# Continent
# Africa               89681472.0                2332636.293         1439089.0
# Asia                721930425.0                1857769.303        10608319.0
# Europe                   5823.0                    536.000              71.0
# North America       173995947.0                3796081.508         1581983.0
# Oceania              36177574.0                  28593.605          490909.0
# ...

# %%
df_continent["number_of_countries"] = df.groupby("Continent").count()["Country"]

# %%
continent_names = df_continent.index.to_list()
sns.relplot(data = df_continent, x = "number_of_countries", y= "Production(Tons)", kind="line", height=4)
plt.xticks(df_continent["number_of_countries"], continent_names, rotation =90)
plt.show()


# Line plot
#sns.relplot(x="number_of_countries", y="Production(Tons)", kind="line", data=df_continent)
#plt.title("Line Plot")
#plt.show()

# Scatter plot instead of line plot
#sns.relplot(x="timepoint", y="signal", kind="scatter", data=data)
#plt.title("Scatter Plot instead of Line Plot")
#plt.show()

# %%
continent_names = df_continent.index.to_list()

# %%
sns.lineplot(data = df_continent,x = "Acreage(Hectare)", y= "Production(Tons)" )
# Out:
# <Axes: xlabel='Acreage(Hectare)', ylabel='Production(Tons)'>

# %%
df_continent["Production(Tons)"].plot(kind = "pie", autopct = "%.2f%%")
plt.title('Production Distribution by Continent')
plt.show()

# %%
df_continent.corr(numeric_only=True)
# Out:
#                            Production(Tons)  Production_per_Person(Kg)  \
# Production(Tons)                   1.000000                   0.522211
# Production_per_Person(Kg)          0.522211                   1.000000
# Acreage(Hectare)                   0.994897                   0.463215
# Yield(Kg/Hectare)                  0.091201                   0.542961
# number_of_countries                0.109244                   0.540086
#
#                            Acreage(Hectare)  Yield(Kg/Hectare)  \
# Production(Tons)                   0.994897           0.091201
# Production_per_Person(Kg)          0.463215           0.542961
# Acreage(Hectare)                   1.000000           0.111166
# Yield(Kg/Hectare)                  0.111166           1.000000
# number_of_countries                0.132817           0.989712
#
#                            number_of_countries
# Production(Tons)                      0.109244
# Production_per_Person(Kg)             0.540086
# ...
